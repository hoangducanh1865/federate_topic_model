# %%
import sys
project_root = "d:/MachineLearning/federated_vae"
sys.path.append(project_root)

# %%
import torch
from main.data.basic_dataset import BasicDataset
import torch.nn as nn
from collections import defaultdict
import numpy as np
from main.utils import _utils

# %%
class BasicTrainer:
    def __init__(self, 
                 model : nn.Module,
                 dataset : BasicDataset,
                 num_top_words = 15,
                 epochs = 200,
                 learning_rate = 0.002,
                 batch_size = 200,
                 verbose = False):
        self.model = model
        self.dataset = dataset
        self.num_top_words = num_top_words
        self.epochs = epochs
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.verbose = verbose
        self.log_interval = 1
        self.data_size = len(self.dataset.train_data)

    def make_optimizer(self):
        return torch.optim.Adam(self.model.parameters(), lr = self.learning_rate)
    
    def train(self):
        optimizer = self.make_optimizer()

        for epoch in range(self.epochs):
            self.model.train()
            total_loss = 0.0
            for batch_data in self.dataset.train_dataloader:
                
                output = self.model(batch_data)

                batch_loss = output['loss']

                optimizer.zero_grad()
                batch_loss.backward()
                optimizer.step()

                total_loss += batch_loss * len(batch_data)

            if (epoch % self.log_interval == 0):    
                print(f"Epoch: {epoch:03d} | Loss: {total_loss / self.data_size}")

        top_words = self.get_top_words()
        train_theta = self.test(self.dataset.train_data)

        return top_words, train_theta

    def test(self, bow):
        data_size = bow.shape[0]
        theta = list()
        all_idx = torch.split(torch.arange(data_size), self.batch_size)

        with torch.no_grad():
            self.model.eval()
            for idx in all_idx:
                batch_input = bow[idx]
                batch_theta = self.model.get_theta(batch_input)
                theta.extend(batch_theta.cpu().tolist())

        theta = np.asarray(theta)
        return theta

    def get_beta(self):
        beta = self.model.get_beta().detach().cpu().numpy()
        return beta

    def get_top_words(self, num_top_words=None):
        if num_top_words is None:
            num_top_words = self.num_top_words
        beta = self.get_beta()
        top_words = _utils.get_top_words(beta, self.dataset.vocab, num_top_words, self.verbose)
        return top_words

    def export_theta(self):
        train_theta = self.test(self.dataset.train_data)
        test_theta = self.test(self.dataset.test_data)
        return train_theta, test_theta

# %%
### test
from main.model.ETM import ETM
test_basic_dataset = BasicDataset(
    dataset_dir = "../../data/20NG"
)
test_model = ETM(test_basic_dataset.vocab_size)
test_basic_trainer = BasicTrainer(
    model=test_model,
    dataset=test_basic_dataset,
    verbose=True,
    epochs = 1
)
# Out:
# train_size:  11314
# test_size:  7532
# vocab_size:  5000
# average length: 110.543

# %%
test_basic_trainer.train()
# Out:
# Epoch: 000 | Loss: 2018.4725341796875
# Topic 0: people replies surface sea lists eliminate simultaneously floppy sensitive determine ian mormons purdue stayed saved
# Topic 1: shown stealth stolen gotten clients transmitted kim taylor erik focus seats speaks glory workstations symptoms
# Topic 2: software class prejudice attempts manufacturer culture irvine bosnia utterly interest extremely giant laughed market hence
# Topic 3: printer clinton quebec biggest convention tapped remains sacred operation inherently management burns enforcement quick volume
# Topic 4: absolutely authorized promote village initial dump nasty vincent involving richardson investment won store nothing water
# Topic 5: dan hunting rich audience explanation dogs modems imply view reserve university hayes saying statistical gives
# Topic 6: equivalent staff apologies clark creator satisfy function document quick member schools skin shit aix workstations
# Topic 7: afraid conner jpeg developers baker pack pitching giant reach saving beautiful hole mode deliberately passes
# Topic 8: suck police abiding user penalty trying reached tends buck ram fear miller rumor either probably
# Topic 9: stop sought nntp usr buy best injuries sufficient special pixel europeans uniform pool divided address
# Topic 10: heard client construction convention belongs glass detect dakota wide auto covington confusing sons concepts drug
# Topic 11: lines many causing hiding exist grand slip heads base lebanese cleveland quoted felt essentially medium
# Topic 12: eisa silicon thru compete svga postscript ignore security ref receiving capacity innocent sigh feels throughout
# Topic 13: line host clayton determined seem loved shipping offers apart useful repost africa anonymous notion finds
# Topic 14: thoughts possibly answered york naturally professor president essence muslims greece medium illinois raw deep australia
# Topic 15: driven bullets firmly briefly default ave impact fail originator picks arms sharks explanation bringing end
# Topic 16: subject anywhere ordered minnesota surgery muslims ages alcohol passed angry nonsense interview explicit optical september
# Topic 17: copies basically ass ref mailer impressed journal des turbo alcohol league offensive fanatic apply topics
# Topic 18: money drugs duty anderson initial distributed handles substance programs brake password ussr fax sony sensitive
# Topic 19: recommended itll human burned complete rod kelly home stuff selling change pointed man senate arrogant
# Topic 20: kit available trip shame encouraged changing weather level temporary articles maintenance stockholm active point alive
# Topic 21: time soon stations belongs multiple territory sandvik stanford dollars turns translation moved triple verify organization
# Topic 22: brad guilt morris roll parties purchase column intel unit rings writers tin hunter silicon baltimore
# Topic 23: conviction ages always gonna tragedy demonstrated pens oriented increases omissions bitnet takes spend inspired gun
# Topic 24: senior hamilton easy scene hall applied rush millions tickets loving read approach one dis slip
# Topic 25: drivers calls rick personnel behavior points telescope canadians ftp specifically giant reaching friends come expensive
# Topic 26: manuals whose safety revolution planning internal plus compiler trivial widespread emergency numerous poor cursor backed
# Topic 27: output wife publications researchers else blown minimal raw beer catch defense trash serve blood handbook
# Topic 28: tradition sold font turn passes irq relate labor considered devil afraid temple editorial passage argic
# Topic 29: something severe russ car yankees twin rotation selection copy bruins documents hundreds jpeg skin ref
# Topic 30: silence engineering looked destroying lowest hardly details nose knock alberta indication amp economy utah feeling
# Topic 31: centuries width longer alpha fields sabres covered flow congress stupidity richard stuff answered complain problem
# Topic 32: reason military closer astronomy argue doubt thomas purchase success forum bird advanced implications channels significant
# Topic 33: control team seconds proposed diego ohanus rod usr israel awesome record russia walk brookline democratic
# Topic 34: interference drink achieve compile papers appropriate deaths jerusalem voluntary fires cliff linear requested denver comfortable
# Topic 35: perfectly able cost telling sahak linux way government locks encounter wanting season ball maple aimed
# Topic 36: nevertheless access express types banned cancer tanks header british yeast stealing produced enhanced terms president
# Topic 37: say drives wind sudden republic professor boring fans press found medium drink adapter newspapers investigate
# Topic 38: world next stuff buttons fiction butt smaller suggest adding cool factor tends regulation valuable uunet
# Topic 39: van age don fbi stations sad converter automatically kick youth brothers exclusive brookline strictly judaism
# Topic 40: article writes importance automatically soviet message sophisticated sweden jays equally knew watched earl score mapping
# Topic 41: messiah signals tip reasoning corp usual worry cars special germany deny classified ministry union class
# Topic 42: writes authority met mustang radiation documentation invasion violent brain switch utilities switching announce verify brookline
# Topic 43: get worth probably probe dictionary begun indiana costs rating kings drugs rob teeth esp readily
# Topic 44: leader enable experimental document genesis coming gross historical installation imagination skin intellect judge suggest acid
# Topic 45: new fascist mark ames interference articles bosnians beings picture decides format language exposed quran experienced
# Topic 46: rules flight friendly meg cache violent wounded cheers likewise arguing listed customer spacecraft explaining classes
# Topic 47: miller every jumpers taylor consideration critical business mapping rear yamaha feed header breaks villages rates
# Topic 48: helping email cause found letter emergency christopher remarks roms palestinian reputation heading sell pictures repeated
# Topic 49: season cease build power laboratory announcement hacker kent stating drove stat com actively locked comparison
# (['people replies surface sea lists eliminate simultaneously floppy sensitive determine ian mormons purdue stayed saved',
#   'shown stealth stolen gotten clients transmitted kim taylor erik focus seats speaks glory workstations symptoms',
#   'software class prejudice attempts manufacturer culture irvine bosnia utterly interest extremely giant laughed market hence',
#   'printer clinton quebec biggest convention tapped remains sacred operation inherently management burns enforcement quick volume',
#   'absolutely authorized promote village initial dump nasty vincent involving richardson investment won store nothing water',
#   'dan hunting rich audience explanation dogs modems imply view reserve university hayes saying statistical gives',
#   'equivalent staff apologies clark creator satisfy function document quick member schools skin shit aix workstations',
#   'afraid conner jpeg developers baker pack pitching giant reach saving beautiful hole mode deliberately passes',
#   'suck police abiding user penalty trying reached tends buck ram fear miller rumor either probably',
#   'stop sought nntp usr buy best injuries sufficient special pixel europeans uniform pool divided address',
#   'heard client construction convention belongs glass detect dakota wide auto covington confusing sons concepts drug',
#   'lines many causing hiding exist grand slip heads base lebanese cleveland quoted felt essentially medium',
#   'eisa silicon thru compete svga postscript ignore security ref receiving capacity innocent sigh feels throughout',
#   'line host clayton determined seem loved shipping offers apart useful repost africa anonymous notion finds',
#   'thoughts possibly answered york naturally professor president essence muslims greece medium illinois raw deep australia',
#   'driven bullets firmly briefly default ave impact fail originator picks arms sharks explanation bringing end',
#   'subject anywhere ordered minnesota surgery muslims ages alcohol passed angry nonsense interview explicit optical september',
#   'copies basically ass ref mailer impressed journal des turbo alcohol league offensive fanatic apply topics',
#   'money drugs duty anderson initial distributed handles substance programs brake password ussr fax sony sensitive',
#   'recommended itll human burned complete rod kelly home stuff selling change pointed man senate arrogant',
#   'kit available trip shame encouraged changing weather level temporary articles maintenance stockholm active point alive',
#   'time soon stations belongs multiple territory sandvik stanford dollars turns translation moved triple verify organization',
#   'brad guilt morris roll parties purchase column intel unit rings writers tin hunter silicon baltimore',
#   'conviction ages always gonna tragedy demonstrated pens oriented increases omissions bitnet takes spend inspired gun',
#   'senior hamilton easy scene hall applied rush millions tickets loving read approach one dis slip',
#   'drivers calls rick personnel behavior points telescope canadians ftp specifically giant reaching friends come expensive',
#   'manuals whose safety revolution planning internal plus compiler trivial widespread emergency numerous poor cursor backed',
#   'output wife publications researchers else blown minimal raw beer catch defense trash serve blood handbook',
#   'tradition sold font turn passes irq relate labor considered devil afraid temple editorial passage argic',
#   'something severe russ car yankees twin rotation selection copy bruins documents hundreds jpeg skin ref',
#   'silence engineering looked destroying lowest hardly details nose knock alberta indication amp economy utah feeling',
#   'centuries width longer alpha fields sabres covered flow congress stupidity richard stuff answered complain problem',
#   'reason military closer astronomy argue doubt thomas purchase success forum bird advanced implications channels significant',
#   'control team seconds proposed diego ohanus rod usr israel awesome record russia walk brookline democratic',
#   'interference drink achieve compile papers appropriate deaths jerusalem voluntary fires cliff linear requested denver comfortable',
#   'perfectly able cost telling sahak linux way government locks encounter wanting season ball maple aimed',
#   'nevertheless access express types banned cancer tanks header british yeast stealing produced enhanced terms president',
#   'say drives wind sudden republic professor boring fans press found medium drink adapter newspapers investigate',
#   'world next stuff buttons fiction butt smaller suggest adding cool factor tends regulation valuable uunet',
#   'van age don fbi stations sad converter automatically kick youth brothers exclusive brookline strictly judaism',
#   'article writes importance automatically soviet message sophisticated sweden jays equally knew watched earl score mapping',
#   'messiah signals tip reasoning corp usual worry cars special germany deny classified ministry union class',
#   'writes authority met mustang radiation documentation invasion violent brain switch utilities switching announce verify brookline',
#   'get worth probably probe dictionary begun indiana costs rating kings drugs rob teeth esp readily',
#   'leader enable experimental document genesis coming gross historical installation imagination skin intellect judge suggest acid',
#   'new fascist mark ames interference articles bosnians beings picture decides format language exposed quran experienced',
#   'rules flight friendly meg cache violent wounded cheers likewise arguing listed customer spacecraft explaining classes',
#   'miller every jumpers taylor consideration critical business mapping rear yamaha feed header breaks villages rates',
#   'helping email cause found letter emergency christopher remarks roms palestinian reputation heading sell pictures repeated',
#   'season cease build power laboratory announcement hacker kent stating drove stat com actively locked comparison'],
#  array([[0.02053696, 0.01291493, 0.01604772, ..., 0.02198964, 0.0208719 ,
#          0.02276361],
#         [0.02079019, 0.01112024, 0.0147781 , ..., 0.02247412, 0.02089847,
#          0.02345552],
#         [0.02090888, 0.01021424, 0.01409869, ..., 0.02269598, 0.02089378,
#          0.02383983],
#         ...,
#         [0.020904  , 0.0100978 , 0.01400545, ..., 0.02273227, 0.02087461,
#          0.02390795],
#         [0.02081041, 0.01097203, 0.01467121, ..., 0.02249768, 0.02090446,
#          0.02351645],
#         [0.02036414, 0.01396977, 0.01676338, ..., 0.02170634, 0.02083816,
#          0.02233883]]))
